# %% [markdown]
# # II.Simulation de l'évolution d'un système chimique.

# %% [markdown]
# <div class = 'alert alert-info'>
# Pour exécuter le code écrit dans un bloc : <b>MAJ-ENTREE </b><br>
#     Pour recommencer depuis le début : Menu <b>Kernel / Restart and clear output </b><br>
#     Toujours exécuter dans l'ordre le code  écrit dans les blocs précédés de la mention <b>Entrée  [  ]</b>
# </div>

# %% [markdown]
# <div class = 'alert alert-warning'>Importation de la bibliothèque de tracé de courbes.
#     </div>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <div class = 'alert alert-warning'>On étudie la transformation entre les ions permanganate et le peroxyde d’hydrogène modélisée par la réaction :
#     $$
#     2 MnO_4^{-}(aq) + 5 H_2O_2(aq)+ 6 H^{+} (aq)\longrightarrow 8 H_2O(l)+ 5 O_2(g) +
#     $$  </div>

# %% [markdown]
# ## II.1. Conditions initiales sur les nombres de moles.

# %%
# Quantités de matière initiales en notant n1_ini et n2_ini respectivement pour MnO4- et H2O2
n1_ini = 
n2_ini =

# %% [markdown]
# ## II.2. Réactif limitant et bilan de matière à l'EF.

# %%
# recherche du réactif limitant et de xmax
if  ...     :# A COMPLETER en remplaçant les ...
    xmax = ...       # A COMPLETER en remplaçant les ...
    print("Le réactif limitant est MnO4- et l’avancement maximal vaut :",xmax,"mol")
else:
    xmax = ...     # A COMPLETER en remplaçant les ...
    print("Le réactif limitant est H2O2 et l’avancement maximal vaut :",xmax, "mol")
    
# bilan de matière à l'état final en notant n3_f et n4_ini respectivement pour O2 et Mn2+
n1_f =             #A COMPLETER 
n2_f =             #A COMPLETER 
n3_f =             #A COMPLETER 
n4_f =             #A COMPLETER 
print("A l'état final, il y a ", n1_f,"mol de MnO4-;" , n2_f,"mol de H2O2;" , n3_f,"mol de O2 et" , n4_f,"mol de Mn2+.")

# %% [markdown]
# ## II.3. Courbes d'évolution des qtités de matières des espèces en fonction de l'avancement.

# %%
# initialisation de la valeur de l'avancement en mol
x=0

#création des listes vides pour chaque qtité de matière et pour l'avancement à l'instant t
n_1=[]
n_2=[]
n_3=[]
n_4=[]
x_t=[]

#Bilan de matière en en mol dans l'état en cours
while x<= ...  :      # A COMPLETER en remplaçant les ...    # condition "tant que la valeur de x est inférieure à ? "
    nbre_1 =       # A COMPLETER  calcul de la quantité de matière de MnO4- dans l'état en cours
    nbre_2 =      # A COMPLETER  calcul de la quantité de matière de H2O2 dans l'état en cours
    nbre_3 =           # A COMPLETER calcul de la quantité de matière de O2 dans l'état en cours
    nbre_4 =         # A COMPLETER calcul de la quantité de matière de Mn2+ dans l'état en cours
    
    n_1.append(nbre_1)        # ajout de la valeur calculée dans la liste de MnO4- 
    n_2.append(nbre_2)         # ajout de la valeur calculée dans la liste de H2O2
    n_3.append(nbre_3)          # ajout de la valeur calculée dans la liste de  O2 
    n_4.append(nbre_4)         # ajout de la valeur calculée dans la liste de Mn2+
    x_t.append(x)              # ajout de la valeur de l'avancement dans la liste
    
    x =                                          # A COMPLETER  on incrémente de 1,0.10^-3 mol la valeur précédente de l'avancement

plt.figure (figsize = (10,8))
plt.plot(x_t,n_1,marker="+")
plt.plot(x_t,n_2,marker="x")
plt.plot(x_t,n_3,marker="o")
plt.plot(x_t,n_4,marker="o")
plt.xlabel('avancement en mol')
plt.ylabel("Quantité de matière de l'espèce en mol")
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %% [markdown]
# <div class = 'alert alert-warning'>
# Imprimer la courbe ci-dessus
#     </div>

# %% [markdown]
# ## C'est fini
# Il ne reste plus qu'à télécharger le fichier !

# %% [markdown]
# <div class = 'alert alert-success'><h4>La commande suivante imprime toutes les lignes de code exécutées depuis la dernière initialisation de la page (Restart and Clear Output) <br><br>Cela permet de les copier dans Spyder ou dans un fichier .text par exemple.</h4></div>

# %%
# %history
